# %%
import urllib
# dartNumber = 21414
from bs4 import BeautifulSoup
# url = ("http://www.ndbc.noaa.gov/station_page.php?station={}".format(dartNumber) + 
#         "&type=0&startyear=2011&startmonth=02&startday=24&endyear=2011&endmonth=03&" + 
#         "endday=26&submit=Submit")
# sock = urllib.request.urlopen(url).read().decode("utf-8")

# soup = BeautifulSoup(sock, 'html.parser')

# %%
def getCoordinatesFromSoup(soup):
    #Find the "meta" with all coordinates

    for meta in soup.find_all('meta'):
        if 'name' in meta.attrs and meta.attrs['name'] =='description':break

    # Parse its content

    s = meta.attrs['content']
    n,e = s[s.find("(")+1:s.find(")")].split()
    n = float(n[:-1]) if n[-1] == 'N' else -float(n[:-1])
    e = float(e[:-1]) if e[-1] == 'E' else -float(e[:-1])
    return e,n

# %%
def readAndWriteDARTBuoy(dartNumber):
    """
        Parses the online website info for the dart buoy,
        saves the time series to a file and returns its soup for further operations
    """
    import urllib
    from bs4 import BeautifulSoup
    url = ("http://www.ndbc.noaa.gov/station_page.php?station={}".format(dartNumber) + 
            "&type=0&startyear=2010&startmonth=02&startday=12&endyear=2010&endmonth=3&" + 
            "endday=12&submit=Submit")
    print(url)
    sock = urllib.request.urlopen(url).read().decode("utf-8")

    soup = BeautifulSoup(sock, 'html.parser')
    fileName = 'dart{}'.format(dartNumber)
        
    f = open(fileName,'w')
    f.write(soup.textarea.contents[0])
    f.close()
    
    print(os.popen('head '+fileName).read())
    
    return soup

# %%
DARTs = [21414, 21419, 21401, 21418, 21413, 52403, 52406, 55012, 51425, 51407,
        46404, 46407, 46411, 46412, 43412, 43413, 32411, 32412,32413,32401]

# %%
coordinates = {}

# %%
import os

# %%
import time

# %%
for dartNumber in DARTs:
    while True:
        time.sleep(0.5)
        print(dartNumber)
        try:
            soup = readAndWriteDARTBuoy(dartNumber)
            coordinates[dartNumber]  = getCoordinatesFromSoup(soup)
        except: 
            print('error')
            continue
        break
# Out:
# 21414
# http://www.ndbc.noaa.gov/station_page.php?station=21414&type=0&startyear=2010&startmonth=02&startday=12&endyear=2010&endmonth=3&endday=12&submit=Submit
# #YY  MM DD hh mm ss T   HEIGHT
# #yr  mo dy hr mn  s -      m
# 2010 03 12 00 00 00 1 9999.000
# 2010 03 11 23 45 00 1 9999.000
# 2010 03 11 23 30 00 1 9999.000
# 2010 03 11 23 15 00 1 9999.000
# 2010 03 11 23 00 00 1 9999.000
# 2010 03 11 22 45 00 1 9999.000
# 2010 03 11 22 30 00 1 9999.000
# 2010 03 11 22 15 00 1 9999.000
#
# 21419
# http://www.ndbc.noaa.gov/station_page.php?station=21419&type=0&startyear=2010&startmonth=02&startday=12&endyear=2010&endmonth=3&endday=12&submit=Submit
# #YY  MM DD hh mm ss T   HEIGHT
# #yr  mo dy hr mn  s -      m
# 2010 03 12 00 00 00 1 9999.000
# 2010 03 11 23 45 00 1 9999.000
# 2010 03 11 23 30 00 1 9999.000
# 2010 03 11 23 15 00 1 9999.000
# 2010 03 11 23 00 00 1 9999.000
# 2010 03 11 22 45 00 1 9999.000
# 2010 03 11 22 30 00 1 9999.000
# 2010 03 11 22 15 00 1 9999.000
#
# 21401
# http://www.ndbc.noaa.gov/station_page.php?station=21401&type=0&startyear=2010&startmonth=02&startday=12&endyear=2010&endmonth=3&endday=12&submit=Submit
# #YY  MM DD hh mm ss T   HEIGHT
# #yr  mo dy hr mn  s -      m
# 2010 03 12 00 00 00 1 9999.000
# 2010 03 11 23 45 00 1 9999.000
# 2010 03 11 23 30 00 1 9999.000
# 2010 03 11 23 15 00 1 9999.000
# 2010 03 11 23 00 00 1 9999.000
# 2010 03 11 22 45 00 1 9999.000
# 2010 03 11 22 30 00 1 9999.000
# 2010 03 11 22 15 00 1 9999.000
#
# 21418
# http://www.ndbc.noaa.gov/station_page.php?station=21418&type=0&startyear=2010&startmonth=02&startday=12&endyear=2010&endmonth=3&endday=12&submit=Submit
# #YY  MM DD hh mm ss T   HEIGHT
# #yr  mo dy hr mn  s -      m
# 2010 03 12 00 00 00 1 5662.874
# 2010 03 11 23 45 00 1 5662.865
# 2010 03 11 23 30 00 1 5662.859
# 2010 03 11 23 15 00 1 5662.855
# 2010 03 11 23 00 00 1 5662.852
# 2010 03 11 22 45 00 1 5662.855
# 2010 03 11 22 30 00 1 5662.854
# 2010 03 11 22 15 00 1 5662.857
#
# 21413
# http://www.ndbc.noaa.gov/station_page.php?station=21413&type=0&startyear=2010&startmonth=02&startday=12&endyear=2010&endmonth=3&endday=12&submit=Submit
# #YY  MM DD hh mm ss T   HEIGHT
# #yr  mo dy hr mn  s -      m
# 2010 03 12 00 00 00 1 5827.560
# 2010 03 11 23 45 00 1 5827.556
# 2010 03 11 23 30 00 1 5827.555
# 2010 03 11 23 15 00 1 5827.555
# 2010 03 11 23 00 00 1 5827.554
# 2010 03 11 22 45 00 1 5827.555
# 2010 03 11 22 30 00 1 5827.555
# 2010 03 11 22 15 00 1 5827.556
#
# 52403
# http://www.ndbc.noaa.gov/station_page.php?station=52403&type=0&startyear=2010&startmonth=02&startday=12&endyear=2010&endmonth=3&endday=12&submit=Submit
# #YY  MM DD hh mm ss T   HEIGHT
# #yr  mo dy hr mn  s -      m
# 2010 03 12 00 00 00 1 4431.768
# 2010 03 11 23 45 00 1 4431.776
# 2010 03 11 23 30 00 1 4431.781
# 2010 03 11 23 15 00 1 4431.789
# 2010 03 11 23 00 00 1 4431.794
# 2010 03 11 22 45 00 1 4431.801
# 2010 03 11 22 30 00 1 4431.806
# 2010 03 11 22 15 00 1 4431.814
#
# 52406
# http://www.ndbc.noaa.gov/station_page.php?station=52406&type=0&startyear=2010&startmonth=02&startday=12&endyear=2010&endmonth=3&endday=12&submit=Submit
# #YY  MM DD hh mm ss T   HEIGHT
# #yr  mo dy hr mn  s -      m
# 2010 03 12 00 00 00 1 9999.000
# 2010 03 11 23 45 00 1 9999.000
# 2010 03 11 23 30 00 1 9999.000
# 2010 03 11 23 15 00 1 9999.000
# 2010 03 11 23 00 00 1 9999.000
# 2010 03 11 22 45 00 1 9999.000
# 2010 03 11 22 30 00 1 9999.000
# 2010 03 11 22 15 00 1 9999.000
#
# 55012
# http://www.ndbc.noaa.gov/station_page.php?station=55012&type=0&startyear=2010&startmonth=02&startday=12&endyear=2010&endmonth=3&endday=12&submit=Submit
# #YY  MM DD hh mm ss T   HEIGHT
# #yr  mo dy hr mn  s -      m
# 2010 03 12 00 00 00 1 3328.209
# 2010 03 11 23 45 00 1 3328.231
# 2010 03 11 23 30 00 1 3328.255
# 2010 03 11 23 15 00 1 3328.279
# 2010 03 11 23 00 00 1 3328.305
# 2010 03 11 22 45 00 1 3328.334
# 2010 03 11 22 30 00 1 3328.359
# 2010 03 11 22 15 00 1 3328.383
#
# 51425
# http://www.ndbc.noaa.gov/station_page.php?station=51425&type=0&startyear=2010&startmonth=02&startday=12&endyear=2010&endmonth=3&endday=12&submit=Submit
# #YY  MM DD hh mm ss T   HEIGHT
# #yr  mo dy hr mn  s -      m
# 2010 03 12 00 00 00 1 4962.660
# 2010 03 11 23 45 00 1 4962.596
# 2010 03 11 23 30 00 1 4962.538
# 2010 03 11 23 15 00 1 4962.484
# 2010 03 11 23 00 00 1 4962.434
# 2010 03 11 22 45 00 1 4962.388
# 2010 03 11 22 30 00 1 4962.349
# 2010 03 11 22 15 00 1 4962.316
#
# 51407
# http://www.ndbc.noaa.gov/station_page.php?station=51407&type=0&startyear=2010&startmonth=02&startday=12&endyear=2010&endmonth=3&endday=12&submit=Submit
# #YY  MM DD hh mm ss T   HEIGHT
# #yr  mo dy hr mn  s -      m
# 2010 03 12 00 00 00 1 9999.000
# 2010 03 11 23 45 00 1 9999.000
# 2010 03 11 23 30 00 1 9999.000
# 2010 03 11 23 15 00 1 9999.000
# 2010 03 11 23 00 00 1 9999.000
# 2010 03 11 22 45 00 1 9999.000
# 2010 03 11 22 30 00 1 9999.000
# 2010 03 11 22 15 00 1 9999.000
#
# 46404
# http://www.ndbc.noaa.gov/station_page.php?station=46404&type=0&startyear=2010&startmonth=02&startday=12&endyear=2010&endmonth=3&endday=12&submit=Submit
# #YY  MM DD hh mm ss T   HEIGHT
# #yr  mo dy hr mn  s -      m
# 2010 03 12 00 00 00 1 9999.000
# 2010 03 11 23 45 00 1 9999.000
# 2010 03 11 23 30 00 1 9999.000
# 2010 03 11 23 15 00 1 9999.000
# 2010 03 11 23 00 00 1 9999.000
# 2010 03 11 22 45 00 1 9999.000
# 2010 03 11 22 30 00 1 9999.000
# 2010 03 11 22 15 00 1 9999.000
#
# 46407
# http://www.ndbc.noaa.gov/station_page.php?station=46407&type=0&startyear=2010&startmonth=02&startday=12&endyear=2010&endmonth=3&endday=12&submit=Submit
# #YY  MM DD hh mm ss T   HEIGHT
# #yr  mo dy hr mn  s -      m
# 2010 03 12 00 00 00 1 3264.890
# 2010 03 11 23 45 00 1 3264.891
# 2010 03 11 23 30 00 1 3264.903
# 2010 03 11 23 15 00 1 3264.926
# 2010 03 11 23 00 00 1 3264.962
# 2010 03 11 22 45 00 1 3265.001
# 2010 03 11 22 30 00 1 3265.057
# 2010 03 11 22 15 00 1 3265.117
#
# 46411
# http://www.ndbc.noaa.gov/station_page.php?station=46411&type=0&startyear=2010&startmonth=02&startday=12&endyear=2010&endmonth=3&endday=12&submit=Submit
# #YY  MM DD hh mm ss T   HEIGHT
# #yr  mo dy hr mn  s -      m
# 2010 03 12 00 00 00 1 4265.585
# 2010 03 11 23 45 00 1 4265.566
# 2010 03 11 23 30 00 1 4265.555
# 2010 03 11 23 15 00 1 4265.554
# 2010 03 11 23 00 00 1 4265.557
# 2010 03 11 22 45 00 1 4265.575
# 2010 03 11 22 30 00 1 4265.600
# 2010 03 11 22 15 00 1 4265.631
#
# 46412
# http://www.ndbc.noaa.gov/station_page.php?station=46412&type=0&startyear=2010&startmonth=02&startday=12&endyear=2010&endmonth=3&endday=12&submit=Submit
# #YY  MM DD hh mm ss T   HEIGHT
# #yr  mo dy hr mn  s -      m
# 2010 03 12 00 00 00 1 3717.124
# 2010 03 11 23 45 00 1 3717.062
# 2010 03 11 23 30 00 1 3717.007
# 2010 03 11 23 15 00 1 3716.951
# 2010 03 11 23 00 00 1 3716.903
# 2010 03 11 22 45 00 1 3716.864
# 2010 03 11 22 30 00 1 3716.829
# 2010 03 11 22 15 00 1 3716.803
#
# 43412
# http://www.ndbc.noaa.gov/station_page.php?station=43412&type=0&startyear=2010&startmonth=02&startday=12&endyear=2010&endmonth=3&endday=12&submit=Submit
# #YY  MM DD hh mm ss T   HEIGHT
# #yr  mo dy hr mn  s -      m
# 2010 03 12 00 00 00 1 3232.948
# 2010 03 11 23 45 00 1 3232.900
# 2010 03 11 23 30 00 1 3232.853
# 2010 03 11 23 15 00 1 3232.809
# 2010 03 11 23 00 00 1 3232.761
# 2010 03 11 22 45 00 1 3232.716
# 2010 03 11 22 30 00 1 3232.674
# 2010 03 11 22 15 00 1 3232.633
#
# 43413
# http://www.ndbc.noaa.gov/station_page.php?station=43413&type=0&startyear=2010&startmonth=02&startday=12&endyear=2010&endmonth=3&endday=12&submit=Submit
# #YY  MM DD hh mm ss T   HEIGHT
# #yr  mo dy hr mn  s -      m
# 2010 03 12 00 00 00 1 9999.000
# 2010 03 11 23 45 00 1 9999.000
# 2010 03 11 23 30 00 1 9999.000
# 2010 03 11 23 15 00 1 9999.000
# 2010 03 11 23 00 00 1 9999.000
# 2010 03 11 22 45 00 1 9999.000
# 2010 03 11 22 30 00 1 9999.000
# 2010 03 11 22 15 00 1 9999.000
#
# 32411
# http://www.ndbc.noaa.gov/station_page.php?station=32411&type=0&startyear=2010&startmonth=02&startday=12&endyear=2010&endmonth=3&endday=12&submit=Submit
# #YY  MM DD hh mm ss T   HEIGHT
# #yr  mo dy hr mn  s -      m
# 2010 03 12 00 00 00 1 3243.190
# 2010 03 11 23 45 00 1 3243.199
# 2010 03 11 23 30 00 1 3243.212
# 2010 03 11 23 15 00 1 3243.231
# 2010 03 11 23 00 00 1 3243.262
# 2010 03 11 22 45 00 1 3243.295
# 2010 03 11 22 30 00 1 3243.341
# 2010 03 11 22 15 00 1 3243.386
#
# 32412
# http://www.ndbc.noaa.gov/station_page.php?station=32412&type=0&startyear=2010&startmonth=02&startday=12&endyear=2010&endmonth=3&endday=12&submit=Submit
# #YY  MM DD hh mm ss T   HEIGHT
# #yr  mo dy hr mn  s -      m
# 2010 03 12 00 00 00 1 4325.623
# 2010 03 11 23 45 00 1 4325.647
# 2010 03 11 23 30 00 1 4325.672
# 2010 03 11 23 15 00 1 4325.694
# 2010 03 11 23 00 00 1 4325.716
# 2010 03 11 22 45 00 1 4325.734
# 2010 03 11 22 30 00 1 4325.755
# 2010 03 11 22 15 00 1 4325.772
# 32413
# http://www.ndbc.noaa.gov/station_page.php?station=32413&type=0&startyear=2010&startmonth=02&startday=12&endyear=2010&endmonth=3&endday=12&submit=Submit
# #YY  MM DD hh mm ss T   HEIGHT
# #yr  mo dy hr mn  s -      m
# 2010 03 12 00 00 00 1 9999.000
# 2010 03 11 23 45 00 1 9999.000
# 2010 03 11 23 30 00 1 9999.000
# 2010 03 11 23 15 00 1 9999.000
# 2010 03 11 23 00 00 1 9999.000
# 2010 03 11 22 45 00 1 9999.000
# 2010 03 11 22 30 00 1 9999.000
# 2010 03 11 22 15 00 1 9999.000
#
# 32401
# http://www.ndbc.noaa.gov/station_page.php?station=32401&type=0&startyear=2010&startmonth=02&startday=12&endyear=2010&endmonth=3&endday=12&submit=Submit
# #YY  MM DD hh mm ss T   HEIGHT
# #yr  mo dy hr mn  s -      m
# 2010 03 12 00 00 00 1 9999.000
# 2010 03 11 23 45 00 1 9999.000
# 2010 03 11 23 30 00 1 9999.000
# 2010 03 11 23 15 00 1 9999.000
# 2010 03 11 23 00 00 1 9999.000
# 2010 03 11 22 45 00 1 9999.000
# 2010 03 11 22 30 00 1 9999.000
# 2010 03 11 22 15 00 1 9999.000

# %%
for k in coordinates.keys():
    print('{}: {{location:[{},{}]}},'.format("'"+str(k)+"'",coordinates[k][0],coordinates[k][1]))
# Out:
# '21414': {location:[178.219,48.968]},
# '21419': {location:[155.717,44.435]},
# '21401': {location:[152.583,42.617]},
# '21418': {location:[148.655,38.728]},
# '21413': {location:[152.132,30.533]},
# '52403': {location:[145.61,4.06]},
# '52406': {location:[165.029,-5.329]},
# '55012': {location:[158.453,-15.664]},
# '51425': {location:[-176.262,-9.505]},
# '51407': {location:[-156.54,19.552]},
# '46404': {location:[-128.775,45.848]},
# '46407': {location:[-128.835,42.705]},
# '46411': {location:[-127.067,39.333]},
# '46412': {location:[-120.582,32.4]},
# '43412': {location:[-106.967,16.045]},
# '43413': {location:[-100.083,11.012]},
# '32411': {location:[-90.88,4.953]},
# '32412': {location:[-86.374,-17.984]},
# '32413': {location:[-93.517,-7.409]},
# '32401': {location:[-73.421,-20.474]},

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

import pandas as pd

# %%
for i,dartNumber in enumerate(DARTs):
    print(dartNumber)
    params = {
        'filepath_or_buffer': 'dart{}'.format(dartNumber),
        'skiprows': 2,
        'delim_whitespace': True,
        'names' : 'year month day hour minute second T height'.split(),
        'na_values': 9999
    }
    df = pd.read_csv(**params)
    df['date'] = pd.to_datetime(df['year month day hour minute second'.split()])
    df = df['date height'.split()]

    plt.plot(df['date'],df['height']-df['height'].mean()+i*1.5)
    plt.text(df['date'].min()-pd.Timedelta(days=4),i*1.5,'{}'.format(dartNumber))
plt.ylim(-2,30)
plt.xlim(df['date'].min()-pd.Timedelta(days=4), df['date'].max())
plt.gca().set_yticks([])
# Out:
# 21414
# 21419
# 21401
# 21418
# 21413
# 52403
# 52406
# 55012
# 51425
# 51407
# 46404
# 46407
# 46411
# 46412
# 43412
# 43413
# 32411
# 32412
# 32413
# 32401
# []

# %% [markdown]
# # Plot on map

# %%
z = np.fromfile('bathymetry3min')

z[0],z[1]
z = np.reshape(z[2:],(int(z[0]),int(z[1])))

# %%
ncols,nrows = z.shape
xll = 90
yll = -70
cell = 1/60*3
xur = xll + (nrows-1)*cell
yur = yll + (ncols-1)*cell

# %%
xur,yur
# Out:
# (325.8, 99.95000000000002)

# %%
x = np.linspace(xll,xur,nrows)
y = np.linspace(yll,yur,ncols)

# %%
skip = 10
plt.pcolormesh(x[::skip], y[::skip], z[::skip, ::skip])
plt.contour(x[::skip], y[::skip], z[::skip, ::skip],[0.0])
for k in coordinates.keys():
    coordinates[k] = list(coordinates[k])
    
    if coordinates[k][0] < 0: 
        coordinates[k][0] = coordinates[k][0] + 360
    plt.scatter(coordinates[k][0] , coordinates[k][1])
    print(coordinates[k])
    plt.text(coordinates[k][0] , coordinates[k][1],'{}'.format(k),color='k')
plt.axis('equal')
# Out:
# [178.219, 48.968]
# [155.717, 44.435]
# [152.583, 42.617]
# [148.655, 38.728]
# [152.132, 30.533]
# [145.61, 4.06]
# [165.029, -5.329]
# [158.453, -15.664]
# [183.738, -9.505]
# [203.46, 19.552]
# [231.225, 45.848]
# [231.165, 42.705]
# [232.933, 39.333]
# [239.418, 32.4]
# [253.03300000000002, 16.045]
# [259.91700000000003, 11.012]
# [269.12, 4.953]
# [273.626, -17.984]
# [266.483, -7.409]
# [286.579, -20.474]
# (90.0, 325.5, -70.0, 99.5)
